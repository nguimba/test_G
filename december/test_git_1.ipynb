# %%
class Drink:
    def __init__(self, volume, expiration):  # initializes drink with volume and expiration
        self.volume = volume          # volume in milliliters
        self.expiration = expiration  # days before expiration
